# %%
from remap_class_scheme import remap_shapefile
reclass_rule = [
    {"new_id": 1,  "new_class": "Hutan Lahan Kering Sekunder", "old_ids": [1]},
    {"new_id": 2,  "new_class": "Hutan Rawa Sekunder",         "old_ids": [2]},
    {"new_id": 3,  "new_class": "Perkebunan Karet",
     "old_ids": [3, 6], "old_names": ["Karet Monokultur", "Agroforestri Karet"]},
    {"new_id": 4,  "new_class": "Sawit Monokultur",            "old_ids": [4]},
    {"new_id": 5,  "new_class": "Pertanian Lahan Kering",      "old_ids": [5]},
    {"new_id": 6,  "new_class": "Sawah",                       "old_ids": [8]},
    {"new_id": 7,  "new_class": "Padang Rumput",                "old_ids": [9]},
    {"new_id": 8,  "new_class": "Permukiman",                  "old_ids": [10]},
    {"new_id": 9,  "new_class": "Lahan Terbuka",                "old_ids": [11]},
    {"new_id": 10, "new_class": "Badan Air",                   "old_ids": [12]},

]

# %%
trainingData = "C:/Users/AFahrezi/Documents/GitHub/generic_rs_code/Class_remapping/Data/TrainingData_2016_OganIlir.shp"
gdf_new = remap_shapefile(trainingData, 
                          "Remap_TD_2016_OganIlir.shp",
                          id_col="ID_epistem", 
                          class_col="NameID", 
                          rules=reclass_rule,
                          drop_unmapped = True,
                          report_path="remap_report.md",)
# Out:
# [remap_classes] Reading: C:\Users\AFahrezi\Documents\GitHub\generic_rs_code\Class_remapping\Data\TrainingData_2016_OganIlir.shp
# [remap_classes] Loaded 766 features. Columns: ['ID_epistem', 'name_epist', 'NameID', 'geometry']
# [remap_classes] WARNING: 1 original (ID, class) pair(s) had no matching rule and were left unmapped:
#     (7, 'Kebun Campuran')
# [remap_classes] Dropped 24 unmapped row(s).
# [remap_classes] Wrote 742 features to: Remap_TD_2016_OganIlir.shp
# [remap_classes] New class summary:
#  new_id                   new_class  count
#       1 Hutan Lahan Kering Sekunder     51
#       2         Hutan Rawa Sekunder     82
#       3            Perkebunan Karet    106
#       4            Sawit Monokultur    106
#       5      Pertanian Lahan Kering     56
#       6                       Sawah     37
#       7               Padang Rumput     24
#       8                  Permukiman    100
#       9               Lahan Terbuka     80
#      10                   Badan Air    100
# [remap_classes] Wrote report to: remap_report.md
