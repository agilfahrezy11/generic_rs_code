# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd() / "raster_mosaicking"))

from raster_mosaic import process_folders

# %%
from pathlib import Path

# Define the folders containing rasters to mosaic, and the shapefiles for clipping
folders = [
    Path(r"C:\Data Spasial\FAO_Binary_Commodities_FPDP\INDONESIA\By Island\Folder_1"),
    Path(r"C:\Data Spasial\FAO_Binary_Commodities_FPDP\INDONESIA\By Island\Folder_2"),
]

aoi_paths = [
    Path(r"C:\Data Spasial\FAO_Binary_Commodities_FPDP\INDONESIA\INDO_AOI.shp"),
]

output_root = Path(r"C:\Data Spasial\FAO_Binary_Commodities_FPDP\INDONESIA\Final Mosaic")

# Run the full workflow automatically
results = process_folders(
    folders=folders,
    aoi_paths=aoi_paths,
    output_root=output_root,
    method="max",
    nodata=0,
    compress="lzw",
)

print(f"Created {len(results)} output rasters")
for path in results:
    print(path)

# %%
# Optional: leave empty; the workflow is now handled by the imported function above.

# %%
# Optional legacy cell left for reference only.
# Use the function-based workflow in the second cell instead.
# Out:
# Raster CRS: EPSG:4326
